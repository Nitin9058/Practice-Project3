# %% [markdown]
# # Import Liabraries

# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("glass.csv")
df
# Out:
#      Id No       RI     NA    MG    AL     SI     K    CA    BA   FE  \
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      TYPE OF GLASS
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...

# %%
df.head()
# Out:
#    Id No       RI     NA    MG    AL     SI     K    CA   BA   FE  \
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    TYPE OF GLASS
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.tail()
# Out:
#      Id No       RI     NA   MG    AL     SI     K    CA    BA   FE  \
# 209    210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0
# 210    211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0
# 211    212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0
# 212    213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0
# 213    214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0
#
#      TYPE OF GLASS
# 209              7
# 210              7
# 211              7
# 212              7
# 213              7

# %%
df.columns
# Out:
# Index(['Id No', 'RI', 'NA', 'MG', 'AL', 'SI', 'K', 'CA', 'BA', 'FE',
#        'TYPE OF GLASS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id No          214 non-null    int64
#  1   RI             214 non-null    float64
#  2   NA             214 non-null    float64
#  3   MG             214 non-null    float64
#  4   AL             214 non-null    float64
#  5   SI             214 non-null    float64
#  6   K              214 non-null    float64
#  7   CA             214 non-null    float64
#  8   BA             214 non-null    float64
#  9   FE             214 non-null    float64
#  10  TYPE OF GLASS  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df.isnull().sum()
# Out:
# Id No            0
# RI               0
# NA               0
# MG               0
# AL               0
# SI               0
# K                0
# CA               0
# BA               0
# FE               0
# TYPE OF GLASS    0
# dtype: int64

# %%
df.shape
# Out:
# (214, 11)

# %%
df.dtypes
# Out:
# Id No              int64
# RI               float64
# NA               float64
# MG               float64
# AL               float64
# SI               float64
# K                float64
# CA               float64
# BA               float64
# FE               float64
# TYPE OF GLASS      int64
# dtype: object

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["TYPE OF GLASS"])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="RI")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="NA")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="MG")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="AL")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="SI")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="K")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="CA")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="BA")
sns.set_theme(style="whitegrid")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="TYPE OF GLASS", y="FE")
sns.set_theme(style="whitegrid")
plt.show()

# %% [markdown]
# # Statistical Analysis

# %%
df.drop(['Id No'],axis=1,inplace=True)
df.sample()
# Out:
#           RI     NA    MG    AL     SI     K   CA   BA   FE  TYPE OF GLASS
# 146  1.51769  13.65  3.66  1.11  72.77  0.11  8.6  0.0  0.0              3

# %%
df.corr()
# Out:
#                      RI        NA        MG        AL        SI         K  \
# RI             1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833
# NA            -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087
# MG            -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396
# AL            -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958
# SI            -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331
# K             -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000
# CA             0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836
# BA            -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618
# FE             0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719
# TYPE OF GLASS -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054
#
#                      CA        BA        FE  TYPE OF GLASS
# RI             0.810403 -0.000386  0.143010      -0.164237
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True,fmt='0.2f')
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=10,linecolor='blue')
plt.show()

# %%
df.describe()
# Out:
#                RI          NA          MG          AL          SI           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                CA          BA          FE  TYPE OF GLASS
# count  214.000000  214.000000  214.000000     214.000000
# mean     8.956963    0.175047    0.057009       2.780374
# std      1.423153    0.497219    0.097439       2.103739
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.describe()[1:].transpose(),annot=True,fmt=".2f",linewidth=10,linecolor='white')
plt.title("new")
plt.show()

# %%
df.skew()
# Out:
# RI               1.625431
# NA               0.454181
# MG              -1.152559
# AL               0.907290
# SI              -0.730447
# K                6.551648
# CA               2.047054
# BA               3.416425
# FE               1.754327
# TYPE OF GLASS    1.114915
# dtype: float64

# %%
sns.distplot(df['RI'])
plt.show()

# %%
sns.distplot(df['NA'])
plt.show()

# %%
sns.distplot(df['MG'])
plt.show()

# %%
sns.distplot(df['AL'])
plt.show()

# %%
sns.distplot(df['SI'])
plt.show()

# %%
sns.distplot(df['K'])
plt.show()

# %%
sns.distplot(df['CA'])
plt.show()

# %%
sns.distplot(df['BA'])
plt.show()

# %%
sns.distplot(df['FE'])
plt.show()

# %%
sns.distplot(df['TYPE OF GLASS'])
plt.show()

# %%
df.drop(['BA','K'],axis=1,inplace=True)
df
# Out:
#           RI     NA    MG    AL     SI    CA   FE  TYPE OF GLASS
# 0    1.52101  13.64  4.49  1.10  71.78  8.75  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  7.83  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  7.78  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  8.22  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  8.07  0.0              1
# ..       ...    ...   ...   ...    ...   ...  ...            ...
# 209  1.51623  14.14  0.00  2.88  72.61  9.18  0.0              7
# 210  1.51685  14.92  0.00  1.99  73.06  8.40  0.0              7
# 211  1.52065  14.36  0.00  2.02  73.42  8.44  0.0              7
# 212  1.51651  14.38  0.00  1.94  73.61  8.48  0.0              7
# 213  1.51711  14.23  0.00  2.08  73.36  8.62  0.0              7
#
# [214 rows x 8 columns]

# %%
df.dtypes
# Out:
# RI               float64
# NA               float64
# MG               float64
# AL               float64
# SI               float64
# CA               float64
# FE               float64
# TYPE OF GLASS      int64
# dtype: object

# %%
df.shape
# Out:
# (214, 8)

# %%
df.columns
# Out:
# Index(['RI', 'NA', 'MG', 'AL', 'SI', 'CA', 'FE', 'TYPE OF GLASS'], dtype='object')

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
#            RI        NA        MG        AL        SI        CA        FE  \
# 0    0.872868  0.284953  1.254639  0.692442  1.127082  0.145766  0.586451
# 1    0.249333  0.591817  0.636168  0.170460  0.102319  0.793734  0.586451
# 2    0.721318  0.149933  0.601422  0.190912  0.438787  0.828949  0.586451
# 3    0.232831  0.242853  0.698710  0.310994  0.052974  0.519052  0.586451
# 4    0.312045  0.169205  0.650066  0.411375  0.555256  0.624699  0.586451
# ..        ...       ...       ...       ...       ...       ...       ...
# 209  0.704815  0.898681  1.865511  2.881125  0.052974  0.157088  0.586451
# 210  0.500178  1.856097  1.865511  1.094342  0.529374  0.392276  0.586451
# 211  0.754046  1.168721  1.865511  1.154570  0.995252  0.364103  0.586451
# 212  0.612399  1.193270  1.865511  0.993960  1.241133  0.335931  0.586451
# 213  0.414363  1.009152  1.865511  1.275028  0.917606  0.237327  0.586451
#
#      TYPE OF GLASS
# 0         0.848275
# 1         0.848275
# ...

# %%
print(np.where(z>3))
# Out:
# (array([105, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112, 131,
#        145, 162, 163, 163, 171, 172, 174, 184, 184, 188, 201], dtype=int64), array([5, 0, 1, 4, 5, 0, 4, 5, 5, 5, 0, 5, 5, 6, 6, 3, 4, 3, 3, 6, 1, 4,
#        4, 4], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print("original shape=",df.shape)
print("new shape=",df_new.shape)
# Out:
# original shape= (214, 8)
# new shape= (198, 8)

# %%
print("percentage loss=",((214-198)/214)*100)
# Out:
# percentage loss= 7.476635514018691

# %%
x=df_new.drop(['TYPE OF GLASS'],axis=1)
x
# Out:
#           RI     NA    MG    AL     SI    CA   FE
# 0    1.52101  13.64  4.49  1.10  71.78  8.75  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  7.83  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  7.78  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  8.22  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  8.07  0.0
# ..       ...    ...   ...   ...    ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  9.18  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  8.40  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  8.44  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  8.48  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  8.62  0.0
#
# [198 rows x 7 columns]

# %%
y=df_new['TYPE OF GLASS']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: TYPE OF GLASS, Length: 198, dtype: int64

# %% [markdown]
# # transformation and scaling

# %%
from sklearn.preprocessing import power_transform

x=power_transform(x,method="yeo-johnson")
x
# Out:
# array([[ 4.85722573e-17,  3.35107362e-01,  2.17050524e+00, ...,
#         -1.49416444e+00,  1.52371411e-02, -6.68397220e-01],
#        [-6.93889390e-18,  6.78661899e-01,  6.09144036e-01, ...,
#         -4.71108781e-02, -1.02429289e+00, -6.68397220e-01],
#        [-2.77555756e-17,  1.79481677e-01,  5.35032559e-01, ...,
#          4.10417512e-01, -1.08549255e+00, -6.68397220e-01],
#        ...,
#        [ 4.16333634e-17,  1.28872728e+00, -1.89180407e+00, ...,
#          1.23269768e+00, -3.17782481e-01, -6.68397220e-01],
#        [-2.08166817e-17,  1.31370629e+00, -1.89180407e+00, ...,
#          1.62386010e+00, -2.73883512e-01, -6.68397220e-01],
#        [-1.73472348e-17,  1.12446033e+00, -1.89180407e+00, ...,
#          1.11281509e+00, -1.22428700e-01, -6.68397220e-01]])

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

x=sc.fit_transform(x)
x

x=pd.DataFrame(x)
x.columns=['RI','NA','MG','AL','SI','CA','FE' ]
x
# Out:
#                RI        NA        MG        AL        SI        CA   FE
# 0    1.561251e-16  0.643587  1.000000  0.409480  0.225725  0.608279  0.0
# 1    1.006140e-16  0.691358  0.615647  0.515034  0.435713  0.475180  0.0
# 2    7.979728e-17  0.621948  0.597403  0.583066  0.502107  0.467344  0.0
# 3    1.006140e-16  0.556724  0.649349  0.487516  0.406445  0.534066  0.0
# 4    9.714451e-17  0.569219  0.623040  0.467469  0.526074  0.511873  0.0
# ..            ...       ...       ...       ...       ...       ...  ...
# 193  7.979728e-17  0.737259  0.000000  1.000000  0.406445  0.664124  0.0
# 194  9.020562e-17  0.869534  0.000000  0.738483  0.520703  0.559983  0.0
# 195  1.491862e-16  0.776187  0.000000  0.748199  0.621431  0.565640  0.0
# 196  8.673617e-17  0.779660  0.000000  0.722125  0.678194  0.571261  0.0
# 197  9.020562e-17  0.753345  0.000000  0.767414  0.604034  0.590652  0.0
#
# [198 rows x 7 columns]

# %% [markdown]
# # Model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0

for i in range(10,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    
    
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        
        
print('Best accuracy is ',(accu*100),'found on random state',(best_rstate))
# Out:
# Best accuracy is  86.63222322265916 found on random state 37

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=37)
Lr=LinearRegression()
Lr.fit(x_train,y_train)
y_pred=Lr.predict(x_test)
score=r2_score(y_test,y_pred)
cvscore=cross_val_score(Lr,x_train,y_train,cv=5).mean()

print(f"r2 score is {score*100} and cross validation score is {cvscore*100}")
# Out:
# r2 score is 86.63222322265916 and cross validation score is 68.13477315735985

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=148)

# %%
import sklearn 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
import warnings 
warnings.filterwarnings('ignore')


model=[LinearRegression(),DecisionTreeRegressor(),GradientBoostingRegressor(),RandomForestClassifier(),KNeighborsClassifier(),SVC()]

for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    m.score(x_train,y_train)
    print('accuracy score of',m,'is:')
    print(r2_score(y_test,predm))
    print("cvscore=",cross_val_score(m,x,y,cv=5).mean())
    print('\n')
# Out:
# accuracy score of LinearRegression() is:
# 0.8663222322265917
# cvscore= -7.630582989457162
#
#
# accuracy score of DecisionTreeRegressor() is:
# 0.812622434204923
# cvscore= -11.924422826958713
#
#
# accuracy score of GradientBoostingRegressor() is:
# 0.7947065383775893
# cvscore= -10.427922555436561
#
#
# accuracy score of RandomForestClassifier() is:
# 0.855208244612895
# cvscore= 0.6661538461538461
#
#
# accuracy score of KNeighborsClassifier() is:
# 0.8722425687760839
# cvscore= 0.6314102564102564
#
#
# accuracy score of SVC() is:
# 0.7913295290009369
# cvscore= 0.6466666666666667

# %% [markdown]
# # Saving the best model

# %%
import pickle
filename="glass.pkl"
pickle.dump(m,open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([7, 2, 3, 2, 1, 1, 2, 7, 7, 1, 1, 2, 2, 2, 1, 7, 2, 2, 5, 5, 2, 7,
#        2, 2, 7, 2, 1, 1, 6, 5, 3, 7, 2, 1, 3, 1, 1, 2, 6, 3, 7, 1, 2, 3,
#        2, 1, 1, 2, 1, 1], dtype=int64)

# %%
predicted=np.array(m.predict(x_test))
predicted
# Out:
# array([7, 2, 1, 1, 1, 1, 2, 7, 7, 1, 2, 2, 2, 2, 2, 7, 2, 2, 5, 6, 1, 7,
#        2, 2, 7, 1, 2, 1, 7, 6, 1, 7, 1, 1, 1, 1, 1, 2, 2, 1, 7, 1, 2, 1,
#        2, 1, 2, 1, 2, 1], dtype=int64)

# %%
import pandas as pd
df_mod=pd.DataFrame({'original':a,'predicted':predicted})
df_mod.head(30)
# Out:
#     original  predicted
# 0          7          7
# 1          2          2
# 2          3          1
# 3          2          1
# 4          1          1
# 5          1          1
# 6          2          2
# 7          7          7
# 8          7          7
# 9          1          1
# 10         1          2
# 11         2          2
# 12         2          2
# 13         2          2
# 14         1          2
# 15         7          7
# 16         2          2
# 17         2          2
# 18         5          5
# 19         5          6
# 20         2          1
# 21         7          7
# 22         2          2
# 23         2          2
# 24         7          7
# 25         2          1
# 26         1          2
# 27         1          1
# 28         6          7
# 29         5          6
